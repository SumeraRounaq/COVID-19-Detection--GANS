# %% [markdown]
# # Getting positive Chest X-Ray images from Cohen repository

# %%
import pandas as pd
import shutil
import os
from pathlib import Path

# %%
# Selecting all combination of 'COVID-19' patients with 'PA' X-Ray view
virus = "Pneumonia/Viral/COVID-19" # Virus to look for
x_ray_view = "PA"   # View of X-Ray


covid_path = ".\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41"
csv = os.path.join(covid_path ,  'metadata.csv')
print(csv)
imageDir = os.path.join(covid_path, 'images')
print(imageDir)

directory = 'COVID19-PA'
parent_dir = Path().absolute()
print(parent_dir)
outputDir = os.path.join(parent_dir, directory)

os.mkdir(outputDir)
print("Directory '% s' created" % directory)


covid_df = pd.read_csv(csv)

covid_df[0:3]
# Out:
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\metadata.csv
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images
# H:\Development\ResearchRelated-Code
# Directory 'COVID19-PA' created
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
#
#                                       location  folder  \
# 0  Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
count=0

for(i, row) in covid_df.iterrows():
    if row["finding"] != virus or row["view"] != x_ray_view:
        continue
    filename = row["filename"].split(os.path.sep)[-1]
    
    inputPath = os.path.sep.join([imageDir,filename])
    print("Input Path:", inputPath)
    outputPath =  os.path.sep.join([outputDir,filename])
    print("Output Path:", outputPath)
    shutil.copy2(inputPath,outputPath)
    count += 1
# Out:
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Output Path: H:\Development\ResearchRelated-Code\COVID19-PA\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Output Path: H:\Development\ResearchRelated-Code\COVID19-PA\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Output Path: H:\Development\ResearchRelated-Code\COVID19-PA\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# ...

# %% [markdown]
# # Getting positive COVID 19-AP images from Cohen repository

# %%
# Selecting all combination of 'COVID-19-AP' patients with 'PA' X-Ray view
virus = "Pneumonia/Viral/COVID-19" # Virus to look for
x_ray_view = "AP"   # View of X-Ray


covid_path = ".\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41"
csv = os.path.join(covid_path ,  'metadata.csv')
print(csv)
imageDir = os.path.join(covid_path, 'images')
print(imageDir)

directory = 'COVID19-AP'
parent_dir = Path().absolute()
outputDir = os.path.join(parent_dir, directory)

os.mkdir(outputDir)
print("Directory '% s' created" % directory)


covid_df = pd.read_csv(csv)

count=0

for(i, row) in covid_df.iterrows():
    if row["finding"] != virus or row["view"] != x_ray_view:
        continue
    filename = row["filename"].split(os.path.sep)[-1]
    
    inputPath = os.path.sep.join([imageDir,filename])
    print("Input Path:", inputPath)
    outputPath =  os.path.sep.join([outputDir,filename])
    print("Output Path:", outputPath)
    shutil.copy2(inputPath,outputPath)
    count += 1
# Out:
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\metadata.csv
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images
# Directory 'COVID19-AP' created
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\jkms-35-e79-g001-l-a.jpg
# Output Path: H:\Development\ResearchRelated-Code\COVID19-AP\jkms-35-e79-g001-l-a.jpg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\jkms-35-e79-g001-l-b.jpg
# Output Path: H:\Development\ResearchRelated-Code\COVID19-AP\jkms-35-e79-g001-l-b.jpg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\jkms-35-e79-g001-l-c.jpg
# Output Path: H:\Development\ResearchRelated-Code\COVID19-AP\jkms-35-e79-g001-l-c.jpg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\1-s2.0-S0929664620300449-gr2_lrg-a.jpg
# ...

# %% [markdown]
# # Getting positive Pneumonia images from Cohen repository

# %%
# Selecting all combination of 'Pneumonia' patients with 'PA' X-Ray view
virus = "Pneumonia" # Virus to look for
x_ray_view = "AP"   # View of X-Ray


covid_path = ".\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41"
csv = os.path.join(covid_path ,  'metadata.csv')
print(csv)
imageDir = os.path.join(covid_path, 'images')
print(imageDir)

directory = 'Pneumonia'
parent_dir = Path().absolute()
outputDir = os.path.join(parent_dir, directory)

os.mkdir(outputDir)
print("Directory '% s' created" % directory)


covid_df = pd.read_csv(csv)

count=0

for(i, row) in covid_df.iterrows():
    if row["finding"] != virus:
        continue
    filename = row["filename"].split(os.path.sep)[-1]
    
    inputPath = os.path.sep.join([imageDir,filename])
    print("Input Path:", inputPath)
    outputPath =  os.path.sep.join([outputDir,filename])
    print("Output Path:", outputPath)
    shutil.copy2(inputPath,outputPath)
    count += 1
# Out:
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\metadata.csv
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images
# Directory 'Pneumonia' created
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\ARDSSevere.png
# Output Path: H:\Development\ResearchRelated-Code\Pneumonia\ARDSSevere.png
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\acute-respiratory-distress-syndrome-ards-1.jpg
# Output Path: H:\Development\ResearchRelated-Code\Pneumonia\acute-respiratory-distress-syndrome-ards-1.jpg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\acute-respiratory-distress-syndrome-ards.jpg
# Output Path: H:\Development\ResearchRelated-Code\Pneumonia\acute-respiratory-distress-syndrome-ards.jpg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\ards-secondary-to-tiger-snake-bite.png
# ...

# %%
# Selecting all combination of 'No Findings' patients 
virus = "No Finding" # Virus to look for
x_ray_view = "X-ray"   # View of X-Ray


covid_path = ".\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41"
csv = os.path.join(covid_path ,  'metadata.csv')
print(csv)
imageDir = os.path.join(covid_path, 'images')
print(imageDir)

directory = 'NoFinding'
parent_dir = Path().absolute()
outputDir = os.path.join(parent_dir, directory)

os.mkdir(outputDir)
print("Directory '% s' created" % directory)


covid_df = pd.read_csv(csv)

count=0

for(i, row) in covid_df.iterrows():
    if row["finding"] != virus and row["modality"] != x_ray_view:
        continue
    filename = row["filename"].split(os.path.sep)[-1]
    
    inputPath = os.path.sep.join([imageDir,filename])
    print("Input Path:", inputPath)
    outputPath =  os.path.sep.join([outputDir,filename])
    print("Output Path:", outputPath)
    shutil.copy2(inputPath,outputPath)
    count += 1
# Out:
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\metadata.csv
# .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images
# Directory 'NoFinding' created
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Output Path: H:\Development\ResearchRelated-Code\NoFinding\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Output Path: H:\Development\ResearchRelated-Code\NoFinding\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# Input Path: .\covid-chestxray-dataset-0.41-Cohen\covid-chestxray-dataset-0.41\images\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# ...
